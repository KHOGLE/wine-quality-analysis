# %%
#Imports
import pandas as pd
import sklearn as skl
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
#Read in Data
red_df = pd.read_csv('../Resources/winequality-red.csv', delimiter=';')
white_df = pd.read_csv('../Resources/winequality-white.csv', delimiter=';')

# %%
#Splitting
target_red = pd.get_dummies(red_df['quality'])
features_red = red_df.drop(columns=['quality', 'fixed acidity', 'volatile acidity', 'citric acid'])

target_white = pd.get_dummies(white_df['quality'])
features_white = white_df.drop(columns=['quality', 'fixed acidity', 'volatile acidity', 'citric acid', 'free sulfur dioxide', 'total sulfur dioxide'])

X_train_red, X_test_red, y_train_red, y_test_red = train_test_split(features_red, target_red, random_state=42)
X_train_white, X_test_white, y_train_white, y_test_white = train_test_split(features_white, target_white, random_state=42)

# %%
#Scaling
X_scaler_red = skl.preprocessing.StandardScaler()
X_scaler_white = skl.preprocessing.StandardScaler()

X_scaler_red.fit(X_train_red)
X_scaler_white.fit(X_train_white)

X_train_scaled_red = X_scaler_red.transform(X_train_red)
X_test_scaled_red = X_scaler_red.transform(X_test_red)

X_train_scaled_white = X_scaler_white.transform(X_train_white)
X_test_scaled_white = X_scaler_white.transform(X_test_white)

# %%
#Create and Evaluate Red Model
inputs = len(features_red.columns)
model_red = tf.keras.models.Sequential()
model_red.add(tf.keras.layers.Dense(units=8, activation='selu', input_dim=inputs))
model_red.add(tf.keras.layers.Dense(units=3, activation='softplus'))
model_red.add(tf.keras.layers.Dense(len(set(red_df['quality'].values)), activation='softmax'))
model_red.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
fit_model_red = model_red.fit(X_train_scaled_red, y_train_red, epochs=30)
model_red_loss, model_red_accuracy = model_red.evaluate(X_test_scaled_red, y_test_red, verbose=2)
print(f'Loss: {model_red_loss}')
print(f'Accuracy: {model_red_accuracy}')
# Out:
# Epoch 1/30
# 38/38 [==============================] - 1s 3ms/step - loss: 2.8788 - accuracy: 0.0984
# Epoch 2/30
# 38/38 [==============================] - 0s 4ms/step - loss: 2.5649 - accuracy: 0.1093
# Epoch 3/30
# 38/38 [==============================] - 0s 5ms/step - loss: 2.3243 - accuracy: 0.1143
# Epoch 4/30
# 38/38 [==============================] - 0s 3ms/step - loss: 2.1374 - accuracy: 0.1209
# Epoch 5/30
# 38/38 [==============================] - 0s 3ms/step - loss: 1.9891 - accuracy: 0.1251
# Epoch 6/30
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8697 - accuracy: 0.1284
# Epoch 7/30
# 38/38 [==============================] - 0s 4ms/step - loss: 1.7727 - accuracy: 0.1309
# Epoch 8/30
# 38/38 [==============================] - 0s 4ms/step - loss: 1.6916 - accuracy: 0.1576
# Epoch 9/30
# 38/38 [==============================] - 0s 7ms/step - loss: 1.6235 - accuracy: 0.2060
# Epoch 10/30
# 38/38 [==============================] - 0s 7ms/step - loss: 1.5645 - accuracy: 0.2736
# Epoch 11/30
# 38/38 [==============================] - 0s 7ms/step - loss: 1.5127 - accuracy: 0.3611
# Epoch 12/30
# 38/38 [==============================] - 0s 4ms/step - loss: 1.4662 - accuracy: 0.4504
# Epoch 13/30
# 38/38 [==============================] - 0s 2ms/step - loss: 1.4245 - accuracy: 0.4754
# Epoch 14/30
# 38/38 [==============================] - 0s 3ms/step - loss: 1.3867 - accuracy: 0.5021
# Epoch 15/30
# 38/38 [==============================] - 0s 4ms/step - loss: 1.3525 - accuracy: 0.5171
# Epoch 16/30
# 38/38 [==============================] - 0s 2ms/step - loss: 1.3214 - accuracy: 0.5346
# Epoch 17/30
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2927 - accuracy: 0.5538
# Epoch 18/30
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2651 - accuracy: 0.5563
# Epoch 19/30
# 38/38 [==============================] - 0s 4ms/step - loss: 1.2371 - accuracy: 0.5613
# Epoch 20/30
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2060 - accuracy: 0.5738
# Epoch 21/30
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1703 - accuracy: 0.5788
# Epoch 22/30
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1296 - accuracy: 0.5813
# Epoch 23/30
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0888 - accuracy: 0.5838
# Epoch 24/30
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0550 - accuracy: 0.5847
# Epoch 25/30
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0317 - accuracy: 0.5905
# Epoch 26/30
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0167 - accuracy: 0.5872
# Epoch 27/30
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0069 - accuracy: 0.5913
# Epoch 28/30
# 38/38 [==============================] - 0s 2ms/step - loss: 0.9992 - accuracy: 0.5947
# Epoch 29/30
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9940 - accuracy: 0.5988
# Epoch 30/30
# 38/38 [==============================] - 0s 4ms/step - loss: 0.9897 - accuracy: 0.5955
# 13/13 - 0s - loss: 1.0175 - accuracy: 0.5600 - 279ms/epoch - 21ms/step
# Loss: 1.017523169517517
# Accuracy: 0.5600000023841858

# %%
#Create and Evaluate White Model
model_white = tf.keras.models.Sequential()
model_white.add(tf.keras.layers.Dense(units=3, activation='relu', input_dim=11))
model_white.add(tf.keras.layers.Dense(units=2, activation='relu'))
model_white.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
model_white.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
fit_model_white = model_white.fit(X_train_scaled_white, y_train_white, epochs=50)
model_loss, model_accuracy = model_white.evaluate(X_test_scaled_white, y_test_white, verbose=2)
print(f'Loss: {model_loss}')
print(f'Accuracy: {model_accuracy}')
# Out:
# Epoch 1/50
# 115/115 [==============================] - 1s 2ms/step - loss: 0.3516 - accuracy: 0.9627
# Epoch 2/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2458 - accuracy: 0.9627
# Epoch 3/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2015 - accuracy: 0.9627
# Epoch 4/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1842 - accuracy: 0.9627
# Epoch 5/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1750 - accuracy: 0.9627
# Epoch 6/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1691 - accuracy: 0.9627
# Epoch 7/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1649 - accuracy: 0.9627
# Epoch 8/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1612 - accuracy: 0.9627
# Epoch 9/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1582 - accuracy: 0.9627
# Epoch 10/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1561 - accuracy: 0.9627
# Epoch 11/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.9627
# Epoch 12/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1522 - accuracy: 0.9627
# Epoch 13/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1508 - accuracy: 0.9627
# Epoch 14/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1496 - accuracy: 0.9627
# Epoch 15/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.1483 - accuracy: 0.9627
# Epoch 16/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1473 - accuracy: 0.9627
# Epoch 17/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1464 - accuracy: 0.9627
# Epoch 18/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.9627
# Epoch 19/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1451 - accuracy: 0.9627
# Epoch 20/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1444 - accuracy: 0.9627
# Epoch 21/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1440 - accuracy: 0.9627
# Epoch 22/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1436 - accuracy: 0.9627
# Epoch 23/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1432 - accuracy: 0.9627
# Epoch 24/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1428 - accuracy: 0.9627
# Epoch 25/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.1426 - accuracy: 0.9627
# Epoch 26/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1423 - accuracy: 0.9627
# Epoch 27/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1420 - accuracy: 0.9627
# Epoch 28/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1418 - accuracy: 0.9627
# Epoch 29/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1418 - accuracy: 0.9627
# Epoch 30/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1415 - accuracy: 0.9627
# Epoch 31/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1413 - accuracy: 0.9627
# Epoch 32/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1410 - accuracy: 0.9627
# Epoch 33/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1409 - accuracy: 0.9627
# Epoch 34/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1406 - accuracy: 0.9627
# Epoch 35/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1405 - accuracy: 0.9627
# Epoch 36/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1403 - accuracy: 0.9627
# Epoch 37/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1401 - accuracy: 0.9627
# Epoch 38/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1400 - accuracy: 0.9627
# Epoch 39/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1399 - accuracy: 0.9627
# Epoch 40/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1397 - accuracy: 0.9627
# Epoch 41/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1395 - accuracy: 0.9627
# Epoch 42/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.1394 - accuracy: 0.9627
# Epoch 43/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1395 - accuracy: 0.9627
# Epoch 44/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1392 - accuracy: 0.9627
# Epoch 45/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1390 - accuracy: 0.9627
# Epoch 46/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1389 - accuracy: 0.9627
# Epoch 47/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1389 - accuracy: 0.9627
# Epoch 48/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1387 - accuracy: 0.9627
# Epoch 49/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1386 - accuracy: 0.9627
# Epoch 50/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1385 - accuracy: 0.9627
# 39/39 - 0s - loss: 0.1340 - accuracy: 0.9649 - 206ms/epoch - 5ms/step
# Loss: 0.1340143233537674
# Accuracy: 0.9648979306221008

# %%
model_red.save('Resources/model_red.h5')
model_white.save('Resources/model_white.h5')
# Out:
# c:\Users\Bryson\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
