# %%
#Imports
import pandas as pd
import sklearn as skl
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
#Read in Data
red_df = pd.read_csv('Resources/winequality-red.csv', delimiter=';')
white_df = pd.read_csv('Resources/winequality-white.csv', delimiter=';')

# %%
#Turn Target Column to Binary
bins = [0, 7, 11]
labels = [0, 1]
red_df['quality'] = pd.cut(red_df['quality'], bins=bins, labels=labels)
white_df['quality'] = pd.cut(white_df['quality'], bins=bins, labels=labels)

# %%
#Splitting
target_red = red_df['quality']
features_red = red_df.drop(columns='quality')

target_white = white_df['quality']
features_white = white_df.drop(columns='quality')

X_train_red, X_test_red, y_train_red, y_test_red = train_test_split(features_red, target_red, random_state=42)
X_train_white, X_test_white, y_train_white, y_test_white = train_test_split(features_white, target_white, random_state=42)

# %%
#Scaling
X_scaler_red = skl.preprocessing.StandardScaler()
X_scaler_white = skl.preprocessing.StandardScaler()

X_scaler_red.fit(X_train_red)
X_scaler_white.fit(X_train_white)

X_train_scaled_red = X_scaler_red.transform(X_train_red)
X_test_scaled_red = X_scaler_red.transform(X_test_red)

X_train_scaled_white = X_scaler_white.transform(X_train_white)
X_test_scaled_white = X_scaler_white.transform(X_test_white)

# %%
#Create and Evaluate Red Model
model_red = tf.keras.models.Sequential()
model_red.add(tf.keras.layers.Dense(units=3, activation='relu', input_dim=11))
model_red.add(tf.keras.layers.Dense(units=2, activation='relu'))
model_red.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
model_red.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
fit_model_red = model_red.fit(X_train_scaled_red, y_train_red, epochs=50)
model_loss, model_accuracy = model_red.evaluate(X_test_scaled_red, y_test_red, verbose=2)
print(f'Loss: {model_loss}')
print(f'Accuracy: {model_accuracy}')
# Out:
# Epoch 1/50
# 38/38 [==============================] - 2s 3ms/step - loss: 0.7261 - accuracy: 0.6414
# Epoch 2/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6341 - accuracy: 0.8657
# Epoch 3/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5642 - accuracy: 0.9758
# Epoch 4/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5081 - accuracy: 0.9883
# Epoch 5/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4595 - accuracy: 0.9892
# Epoch 6/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4140 - accuracy: 0.9892
# Epoch 7/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.3705 - accuracy: 0.9892
# Epoch 8/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.3318 - accuracy: 0.9892
# Epoch 9/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2979 - accuracy: 0.9892
# Epoch 10/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2681 - accuracy: 0.9892
# Epoch 11/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2406 - accuracy: 0.9892
# Epoch 12/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.2148 - accuracy: 0.9892
# Epoch 13/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1913 - accuracy: 0.9892
# Epoch 14/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1700 - accuracy: 0.9892
# Epoch 15/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1520 - accuracy: 0.9892
# Epoch 16/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1365 - accuracy: 0.9892
# Epoch 17/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1236 - accuracy: 0.9892
# Epoch 18/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1128 - accuracy: 0.9892
# Epoch 19/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.1036 - accuracy: 0.9892
# Epoch 20/50
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0961 - accuracy: 0.9892
# Epoch 21/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0898 - accuracy: 0.9892
# Epoch 22/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0844 - accuracy: 0.9892
# Epoch 23/50
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0799 - accuracy: 0.9892
# Epoch 24/50
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0761 - accuracy: 0.9892
# Epoch 25/50
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0729 - accuracy: 0.9892
# Epoch 26/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0703 - accuracy: 0.9892
# Epoch 27/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0680 - accuracy: 0.9892
# Epoch 28/50
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0659 - accuracy: 0.9892
# Epoch 29/50
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0644 - accuracy: 0.9892
# Epoch 30/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0629 - accuracy: 0.9892
# Epoch 31/50
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0619 - accuracy: 0.9892
# Epoch 32/50
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0606 - accuracy: 0.9892
# Epoch 33/50
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0596 - accuracy: 0.9892
# Epoch 34/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0587 - accuracy: 0.9892
# Epoch 35/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0578 - accuracy: 0.9892
# Epoch 36/50
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0572 - accuracy: 0.9892
# Epoch 37/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0563 - accuracy: 0.9892
# Epoch 38/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0556 - accuracy: 0.9892
# Epoch 39/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0549 - accuracy: 0.9892
# Epoch 40/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0543 - accuracy: 0.9892
# Epoch 41/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0538 - accuracy: 0.9892
# Epoch 42/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0531 - accuracy: 0.9892
# Epoch 43/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0526 - accuracy: 0.9892
# Epoch 44/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0521 - accuracy: 0.9892
# Epoch 45/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0518 - accuracy: 0.9892
# Epoch 46/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0513 - accuracy: 0.9892
# Epoch 47/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0510 - accuracy: 0.9892
# Epoch 48/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0506 - accuracy: 0.9892
# Epoch 49/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0503 - accuracy: 0.9892
# Epoch 50/50
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0501 - accuracy: 0.9892
# 13/13 - 1s - loss: 0.0520 - accuracy: 0.9875 - 540ms/epoch - 42ms/step
# Loss: 0.052022166550159454
# Accuracy: 0.987500011920929

# %%
#Create and Evaluate White Model
model_white = tf.keras.models.Sequential()
model_white.add(tf.keras.layers.Dense(units=3, activation='relu', input_dim=11))
model_white.add(tf.keras.layers.Dense(units=2, activation='relu'))
model_white.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
model_white.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
fit_model_white = model_white.fit(X_train_scaled_white, y_train_white, epochs=50)
model_loss, model_accuracy = model_white.evaluate(X_test_scaled_white, y_test_white, verbose=2)
print(f'Loss: {model_loss}')
print(f'Accuracy: {model_accuracy}')
# Out:
# Epoch 1/50
# 115/115 [==============================] - 1s 2ms/step - loss: 0.5464 - accuracy: 0.9627
# Epoch 2/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.3906 - accuracy: 0.9627
# Epoch 3/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.2784 - accuracy: 0.9627
# Epoch 4/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2145 - accuracy: 0.9627
# Epoch 5/50
# 115/115 [==============================] - 1s 4ms/step - loss: 0.1778 - accuracy: 0.9627
# Epoch 6/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1629 - accuracy: 0.9627
# Epoch 7/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.1568 - accuracy: 0.9627
# Epoch 8/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1532 - accuracy: 0.9627
# Epoch 9/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.1510 - accuracy: 0.9627
# Epoch 10/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.1496 - accuracy: 0.9627
# Epoch 11/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1485 - accuracy: 0.9627
# Epoch 12/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.1478 - accuracy: 0.9627
# Epoch 13/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1469 - accuracy: 0.9627
# Epoch 14/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1462 - accuracy: 0.9627
# Epoch 15/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1455 - accuracy: 0.9627
# Epoch 16/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1449 - accuracy: 0.9627
# Epoch 17/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.1444 - accuracy: 0.9627
# Epoch 18/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.1439 - accuracy: 0.9627
# Epoch 19/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1434 - accuracy: 0.9627
# Epoch 20/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1429 - accuracy: 0.9627
# Epoch 21/50
# 115/115 [==============================] - 1s 5ms/step - loss: 0.1426 - accuracy: 0.9627
# Epoch 22/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.1422 - accuracy: 0.9627
# Epoch 23/50
# 115/115 [==============================] - 1s 5ms/step - loss: 0.1418 - accuracy: 0.9627
# Epoch 24/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1415 - accuracy: 0.9627
# Epoch 25/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1411 - accuracy: 0.9627
# Epoch 26/50
# 115/115 [==============================] - 1s 4ms/step - loss: 0.1408 - accuracy: 0.9627
# Epoch 27/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1406 - accuracy: 0.9627
# Epoch 28/50
# 115/115 [==============================] - 1s 5ms/step - loss: 0.1404 - accuracy: 0.9627
# Epoch 29/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1401 - accuracy: 0.9627
# Epoch 30/50
# 115/115 [==============================] - 1s 7ms/step - loss: 0.1400 - accuracy: 0.9627
# Epoch 31/50
# 115/115 [==============================] - 1s 7ms/step - loss: 0.1398 - accuracy: 0.9627
# Epoch 32/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1397 - accuracy: 0.9627
# Epoch 33/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1394 - accuracy: 0.9627
# Epoch 34/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1393 - accuracy: 0.9627
# Epoch 35/50
# 115/115 [==============================] - 1s 5ms/step - loss: 0.1391 - accuracy: 0.9627
# Epoch 36/50
# 115/115 [==============================] - 1s 4ms/step - loss: 0.1389 - accuracy: 0.9627
# Epoch 37/50
# 115/115 [==============================] - 1s 5ms/step - loss: 0.1389 - accuracy: 0.9627
# Epoch 38/50
# 115/115 [==============================] - 1s 4ms/step - loss: 0.1386 - accuracy: 0.9627
# Epoch 39/50
# 115/115 [==============================] - 1s 5ms/step - loss: 0.1385 - accuracy: 0.9627
# Epoch 40/50
# 115/115 [==============================] - 1s 6ms/step - loss: 0.1383 - accuracy: 0.9627
# Epoch 41/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1382 - accuracy: 0.9627
# Epoch 42/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1381 - accuracy: 0.9627
# Epoch 43/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1381 - accuracy: 0.9627
# Epoch 44/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1379 - accuracy: 0.9627
# Epoch 45/50
# 115/115 [==============================] - 1s 4ms/step - loss: 0.1378 - accuracy: 0.9627
# Epoch 46/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.1378 - accuracy: 0.9627
# Epoch 47/50
# 115/115 [==============================] - 0s 4ms/step - loss: 0.1377 - accuracy: 0.9627
# Epoch 48/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.1375 - accuracy: 0.9627
# Epoch 49/50
# 115/115 [==============================] - 1s 9ms/step - loss: 0.1375 - accuracy: 0.9627
# Epoch 50/50
# 115/115 [==============================] - 1s 6ms/step - loss: 0.1374 - accuracy: 0.9627
# 39/39 - 1s - loss: 0.1308 - accuracy: 0.9649 - 573ms/epoch - 15ms/step
# Loss: 0.1308460235595703
# Accuracy: 0.9648979306221008

# %%
model_red.save('Resources/model.h5')
# Out:
# c:\Users\Bryson\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
